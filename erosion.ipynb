# %% [markdown]
# <a href="https://colab.research.google.com/github/ea-castrobelmont/Vision-Computacional/blob/main/erosion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow

# Cargar la imagen
img = cv2.imread('/content/morelos.jpg', 0)

# Crear un elemento estructurante con forma de cruz y tamaño 3x3
kernel = np.ones((3,3),np.uint8)

# Aplicar erosión a la imagen
erosion = cv2.erode(img, kernel, iterations = 1)

# Mostrar la imagen resultante
comparacion = cv2.hconcat([img, erosion])
print("---------------------------------------Original--------------------------------|--------------------------------------Erosión----------------------------------")
cv2_imshow(comparacion)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------Original--------------------------------|--------------------------------------Erosión-----------------------------------
# <PIL.Image.Image image mode=L size=1224x408 at 0x7FE988102850>
